# %%
#Import packages

from bs4 import BeautifulSoup
import urllib
import pandas as pd
from urllib.request import urlopen
from urllib.request import urlopen
import lxml


#!pip3 install selenium
from selenium import webdriver    #open webdriver for specific browser
from selenium.webdriver.common.keys import Keys   # for necessary browser action
from selenium.webdriver.common.by import By    # For selecting html code
import time 
from selenium.webdriver.chrome.options import Options


from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC

# %%
# Selenium Version 1.1

company = []
location = []
#date = []
job_level = []
emp_type = []
job_function = []
job_industry = []
jd = []



driver = webdriver.Chrome()
driver.get("https://www.linkedin.com/jobs/search/?geoId=103644278&keywords=data%20analyst&location=United%20States")
pageSource = driver.page_source

for i in range(2):
    driver.execute_script("window.scrollTo(0,document.body.scrollHeight);")
    soup = BeautifulSoup(pageSource, 'lxml')
    a_tag = soup.find_all(lambda tag: tag.name == 'a' and tag.get('class')==['result-card__full-card-link'])
    
    for url in a_tag:
        match_link = url.get('href')
        print(match_link)
        
         # Job Description
        des = jd_soup.find_all('div', class_='show-more-less-html__markup show-more-less-html__markup--clamp-after-5')
        for job_d in des:
            text = job_d.text
            jd.append(text) 
            #print(len(jd))
        
        
        #Company Title
        name = jd_soup.find_all('a', class_='topcard__org-name-link topcard__flavor--black-link') 
        for i in name:
            txt = i.text
            company.append(txt)
            print(len(company))
            #print(company)
    
    
        #Company Location
        loc = jd_soup.find_all('span', class_='sub-nav-cta__meta-text') 
        for j in loc:
            location_ = j.text
            location.append(location_)
            #print(location)

        #Date of the Job Post
        #date_of_post = jd_soup.find_all('time')
        #for time in date_of_post:
            #t=time.text
            #date.append(t)
            #print(date)
    
        #Job Level
        req_level = jd_soup.find_all('span', class_='job-criteria__text job-criteria__text--criteria')[0]
        for job in req_level:
            job_level.append(job)
            #print(job_level)
    
        #Employment Type
        emp = jd_soup.find_all('span', class_='job-criteria__text job-criteria__text--criteria')[1]
        for em_type in emp:
            emp_type.append(em_type)
            #print(emp_type)
        
        #Job Function (Same Job Function)
        fun = jd_soup.find_all('span', class_='job-criteria__text job-criteria__text--criteria')[2]
        for function in fun:
            job_function.append(function)
            #print(job_function)
        
        # Industry
        Ind = jd_soup.find_all('span', class_='job-criteria__text job-criteria__text--criteria')[3]
        for industry in Ind:
            job_industry.append(industry)
            #print(job_function)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# //anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     376             try:  # Python 2.7, use buffering of HTTP responses
# --> 377                 httplib_response = conn.getresponse(buffering=True)
#     378             except TypeError:  # Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-b05e4a94af8e> in <module>
#      14
#      15 driver = webdriver.Chrome()
# ---> 16 driver.get("https://www.linkedin.com/jobs/search/?geoId=103644278&keywords=data%20analyst&location=United%20States")
#      17 pageSource = driver.page_source
# ...

# %%
# Selenium Version 1.2

company = []
location = []
#date = []
job_level = []
emp_type = []
job_function = []
job_industry = []
jd = []

driver = webdriver.Chrome()
driver.get("https://www.linkedin.com/jobs/search?keywords=Data%2BAnalyst&location=United%2BStates&trk=public_jobs_jobs-search-bar_search-submit&sortBy=DD&redirect=false&position=1&pageNum=0")

for i in range(0,50):
    driver.execute_script("window.scrollTo(0,document.body.scrollHeight);")    
    time.sleep(3)
    pageSource = driver.page_source
    soup = BeautifulSoup(pageSource, 'lxml')
    
    a_tag = soup.find_all(lambda tag: tag.name == 'a' and tag.get('class')==['result-card__full-card-link'])
    
for url in a_tag:
    match_link = url.get('href')
    print(match_link)
    page2 = urlopen(match_link)
    jd_soup = BeautifulSoup(page2, 'html') # Done!
        
  # Job Description
    des = jd_soup.find_all('div', class_='show-more-less-html__markup show-more-less-html__markup--clamp-after-5')
    for job_d in des:
        text = job_d.text
        jd.append(text) 
            #print(len(jd))
        
        
    #Company Title
    name = jd_soup.find_all('a', class_='topcard__org-name-link topcard__flavor--black-link') 
    for i in name:
        txt = i.text
        company.append(txt)
        print(len(company))
            #print(company)
    
    
    #Company Location
    loc = jd_soup.find_all('span', class_='sub-nav-cta__meta-text') 
    for j in loc:
        location_ = j.text
        location.append(location_)
            #print(location)

        #Date of the Job Post
        #date_of_post = jd_soup.find_all('time')
        #for time in date_of_post:
            #t=time.text
            #date.append(t)
            #print(date)
    
    #Job Level
    req_level = jd_soup.find_all('span', class_='job-criteria__text job-criteria__text--criteria')[0]
    for job in req_level:
        job_level.append(job)
            #print(job_level)
    
    #Employment Type
    emp = jd_soup.find_all('span', class_='job-criteria__text job-criteria__text--criteria')[1]
    for em_type in emp:
        emp_type.append(em_type)
            #print(emp_type)
        
    #Job Function (Same Job Function)
    fun = jd_soup.find_all('span', class_='job-criteria__text job-criteria__text--criteria')[2]
    for function in fun:
        job_function.append(function)
            #print(job_function)
        
    # Industry
    Ind = jd_soup.find_all('span', class_='job-criteria__text job-criteria__text--criteria')[3]
    for industry in Ind:
        job_industry.append(industry)
            #print(job_function)
# Out:
# https://www.linkedin.com/jobs/view/chief-data-and-analytics-officer-at-mayo-clinic-1956007101?refId=0f222b9c-3d18-404f-b158-2543588001c3&position=1&pageNum=0&trk=public_jobs_job-result-card_result-card_full-click
# 1
# https://www.linkedin.com/jobs/view/quality-data-analyst-at-kuehne%2Bnagel-1912763455?refId=0f222b9c-3d18-404f-b158-2543588001c3&position=2&pageNum=0&trk=public_jobs_job-result-card_result-card_full-click
# 2
# https://www.linkedin.com/jobs/view/quality-data-analyst-texas-or-telecommute-at-wellmed-medical-management-1930389301?refId=0f222b9c-3d18-404f-b158-2543588001c3&position=3&pageNum=0&trk=public_jobs_job-result-card_result-card_full-click
# 3
# https://www.linkedin.com/jobs/view/all-source-intelligence-analyst-charlottesville-va-with-security-clearance-at-clearancejobs-1939095715?refId=0f222b9c-3d18-404f-b158-2543588001c3&position=4&pageNum=0&trk=public_jobs_job-result-card_result-card_full-click
# 4
# ...

# %%
# Selenium Version 1.3 (with "show more" button)

company = []
location = []
#date = []
job_level = []
emp_type = []
job_function = []
job_industry = []
jd = []

driver = webdriver.Chrome()
driver.get("https://www.linkedin.com/jobs/search/?geoId=103644278&keywords=data%20analyst&location=United%20States")



for i in range(0,50):
    driver.execute_script("window.scrollTo(0,document.body.scrollHeight);")    
    driver.find_element_by_xpath('//span[contains(., "More")]/..').click()    
    time.sleep(3)
    pageSource = driver.page_source
    soup = BeautifulSoup(pageSource, 'lxml')
    
    a_tag = soup.find_all(lambda tag: tag.name == 'a' and tag.get('class')==['result-card__full-card-link'])


    
for url in a_tag:
    match_link = url.get('href')
    print(match_link)
    page2 = urlopen(match_link)
    jd_soup = BeautifulSoup(page2, 'html') # Done!
        
  # Job Description
    des = jd_soup.find_all('div', class_='show-more-less-html__markup show-more-less-html__markup--clamp-after-5')
    for job_d in des:
        text = job_d.text
        jd.append(text) 
            #print(len(jd))
        
        
    #Company Title
    name = jd_soup.find_all('a', class_='topcard__org-name-link topcard__flavor--black-link') 
    for i in name:
        txt = i.text
        company.append(txt)
        print(len(company))
            #print(company)
    
    
    #Company Location
    loc = jd_soup.find_all('span', class_='sub-nav-cta__meta-text') 
    for j in loc:
        location_ = j.text
        location.append(location_)
            #print(location)

        #Date of the Job Post
        #date_of_post = jd_soup.find_all('time')
        #for time in date_of_post:
            #t=time.text
            #date.append(t)
            #print(date)
    
    #Job Level
    req_level = jd_soup.find_all('span', class_='job-criteria__text job-criteria__text--criteria')[0]
    for job in req_level:
        job_level.append(job)
            #print(job_level)
    
    #Employment Type
    emp = jd_soup.find_all('span', class_='job-criteria__text job-criteria__text--criteria')[1]
    for em_type in emp:
        emp_type.append(em_type)
            #print(emp_type)
        
    #Job Function (Same Job Function)
    fun = jd_soup.find_all('span', class_='job-criteria__text job-criteria__text--criteria')[2]
    for function in fun:
        job_function.append(function)
            #print(job_function)
        
    # Industry
    Ind = jd_soup.find_all('span', class_='job-criteria__text job-criteria__text--criteria')[3]
    for industry in Ind:
        job_industry.append(industry)
            #print(job_function)

# %%
from pandas import DataFrame

table = {'company': company,
         'location': location,
         'jd':jd,
         'emp_type': emp_type,
         'job_level': job_level,
         'job_function': job_function,
         'job_industry': job_industry,
         
        }
df = pd.DataFrame.from_dict(table, orient='index')
df = df.transpose()
df
# Out:
#                               company             location  \
# 0                         Mayo Clinic        Rochester, MN
# 1                        Kuehne+Nagel       Whitestown, IN
# 2          WellMed Medical Management      San Antonio, TX
# 3                       ClearanceJobs  Charlottesville, VA
# 4                       ClearanceJobs  Charlottesville, VA
# ..                                ...                  ...
# 170  Digital Technology International        Charlotte, NC
# 171                            AbbVie        Schneider, IN
# 172          The Camp Recovery Center          Detroit, MI
# 173                       CyberCoders           Denver, CO
# 174                       CyberCoders       Washington, DC
#
#                                                     jd   emp_type  \
# 0    Position descriptionThis position may be locat...  Full-time
# 1    The Quality Analyst will be responsible for as...  Full-time
# ...

# %%
df.to_csv('Prisme LinkedIn Scrape Project(s.175).csv')

# %% [markdown]
# ## Selenium - Problem:
# Some job posting dates are missing. Unable to replace it with N/A

# %%
len(df['company'].unique())

# %%
# Selenium Version 1.2 (trial: date)

company = []

date = []


driver = webdriver.Chrome()
result = driver.get("https://www.linkedin.com/jobs/search/?geoId=103644278&keywords=data%20analyst&location=United%20States")
pageSource = driver.page_source

for i in range(0,2):
    driver.execute_script("window.scrollTo(0,document.body.scrollHeight);")
    soup = BeautifulSoup(pageSource, 'lxml')
    a_tag = soup.find_all(lambda tag: tag.name == 'a' and tag.get('class')==['result-card__full-card-link'])
    
    for url in a_tag:
        match_link = url.get('href')
        page2 = urlopen(match_link)
    
        jd_soup = BeautifulSoup(page2, 'html') # Done!
    

        #Company Title
        name = jd_soup.find_all('a', class_='topcard__org-name-link topcard__flavor--black-link') 
        for i in name:
            txt = i.text
            company.append(txt)
            #print(len(company))
            #print(company)
    
    

        #Date of the Job Post
        
        date_of_post = jd_soup.find_all('span', class_='topcard__flavor--metadata posted-time-ago__text')
        #print(date_of_post)
        for time in date_of_post:
            date.append([time.text if time.text else 0])
            #if time == '':
                #time == 'No Number'
                
            #else: 
                #time = time.text
            #date.append(t)            
            #if t == '':
                #t == 'no number'
            #date.append(t)
            #date.append(t)
        print(date)

# %% [markdown]
# # Beautiful Soup Version 1 - Problem:
# Able to turn each page but scraping duplicates

# %%
# Beautiful Soup Version 1
import requests

company = []
location = []
#date = []
job_level = []
emp_type = []
job_function = []
job_industry = []
jd = []
    
link = "https://www.linkedin.com/jobs/search/?geoId=103644278&keywords=data%20analyst&location=United%20States"


for num in range(1,3):
    result = requests.get(link)
    page = result.content
    soup = BeautifulSoup(page, 'lxml')
    a_tag = soup.find_all(lambda tag: tag.name == 'a' and tag.get('class')==['result-card__full-card-link'])

    for i in a_tag:
        match_link = i.get('href')
        #print(match_link)
        page2 = urlopen(match_link)
        jd_soup = BeautifulSoup(page2, 'html') # Done!
        
  # Job Description
        des = jd_soup.find_all('div', class_='show-more-less-html__markup show-more-less-html__markup--clamp-after-5')
        for job_d in des:
            text = job_d.text
            jd.append(text) 
            #print(len(jd))
        
        
    #Company Title
        name = jd_soup.find_all('a', class_='topcard__org-name-link topcard__flavor--black-link') 
        for i in name:
            txt = i.text
            company.append(txt)
            #print(len(company))
            #print(company)
    
    
    #Company Location
        loc = jd_soup.find_all('span', class_='sub-nav-cta__meta-text') 
        for j in loc:
            location_ = j.text
            location.append(location_)
            #print(location)

        #Date of the Job Post
        #date_of_post = jd_soup.find_all('time')
        #for time in date_of_post:
            #t=time.text
            #date.append(t)
            #print(date)
    
    #Job Level
        req_level = jd_soup.find_all('span', class_='job-criteria__text job-criteria__text--criteria')[0]
        for job in req_level:
            job_level.append(job)
            #print(job_level)
    
    #Employment Type
        emp = jd_soup.find_all('span', class_='job-criteria__text job-criteria__text--criteria')[1]
        for em_type in emp:
            emp_type.append(em_type)
                #print(emp_type)
        
    #Job Function (Same Job Function)
        fun = jd_soup.find_all('span', class_='job-criteria__text job-criteria__text--criteria')[2]
        for function in fun:
            job_function.append(function)
            #print(job_function)
        
    # Industry
        Ind = jd_soup.find_all('span', class_='job-criteria__text job-criteria__text--criteria')[3]
        for industry in Ind:
            job_industry.append(industry)
            #print(job_function)
            
    link = 'https://www.linkedin.com/jobs/search/?geoId=103644278&keywords=data%20analyst&location=United%20States%3Fstart&start' + str(num*25)
    print(link)

# %%
from pandas import DataFrame

table = {'company': company,
         'location': location,
         'jd':jd,
         'emp_type': emp_type,
         'job_level': job_level,
         'job_function': job_function,
         'job_industry': job_industry,
         
        }
df = pd.DataFrame.from_dict(table, orient='index')
df = df.transpose()
df

# %%
df.to_csv('Prisme LinkedIn Scrape Project (try).csv')

# %%
driver = webdriver.Chrome()
driver.get("https://www.linkedin.com/jobs/search/?geoId=103644278&keywords=data%20analyst&location=United%20States")

for i in range(0,3):
    driver.execute_script("window.scrollTo(0,document.body.scrollHeight);")    
    time.sleep(3)
    pageSource = driver.page_source
    soup = BeautifulSoup(pageSource, 'lxml')
    
    a_tag = soup.find_all(lambda tag: tag.name == 'a' and tag.get('class')==['result-card__full-card-link'])
    
for url in a_tag:
    match_link = url.get('href')
    print(match_link)

# %%
print(len(job_level))

# %%
print(job_level)

# %%
print(jd[24])
